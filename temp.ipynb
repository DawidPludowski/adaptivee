# %%
from pathlib import Path
import numpy as np

path = 'resources/liltab/split/encoder/test/nomao.npz'
data = np.load(path, allow_pickle=True)

# %%
data['SIMPLE-1-alpha=1.0']
# Out:
# array([[0.19972154, 0.20006962, 0.20006962, 0.20006962, 0.20006962],
#        [0.19987235, 0.20003191, 0.20003191, 0.20003191, 0.20003191],
#        [0.19970638, 0.2000734 , 0.2000734 , 0.2000734 , 0.2000734 ],
#        ...,
#        [0.19371481, 0.2015713 , 0.2015713 , 0.2015713 , 0.2015713 ],
#        [0.23083243, 0.09404929, 0.25565248, 0.24809681, 0.17136898],
#        [0.19926876, 0.08900431, 0.24193879, 0.22784937, 0.24193879]],
#       shape=(34465, 5))
