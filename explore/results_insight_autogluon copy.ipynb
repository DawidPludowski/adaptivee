# %%
import os
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import pandas as pd
from sklearn.manifold import TSNE

# %%
os.chdir('..')

# %%
import importlib
from Orange.evaluation import scoring
_ = importlib.reload( scoring )

from analysis.auto_report import AutoSummaryReport

# %% [markdown]
# # Best method vs AutoGluon

# %%
path = 'report/2024-10-13_21-31-00'
report = AutoSummaryReport(path)
weights_metrics = report.get_weights_metrics()
weights_metrics
# Out:
#      data_name                     experiment_name        norm           std  \
# 0          kc1  LiltabEncoder;model_path=resources   18.012599  1.665335e-17
# 0    numerai28  LiltabEncoder;model_path=resources  118.298395  2.081668e-17
# 0  qsar-biodeg  LiltabEncoder;model_path=resources   11.484852  3.700743e-17
# 0         wilt  LiltabEncoder;model_path=resources   21.880976  5.551115e-17
#
#    std_target
# 0    0.331857
# 0    0.420245
# 0    0.383017
# 0    0.364795

# %%
path = 'report/2024-10-13_21-42-03'
report = AutoSummaryReport(path)
weights_metrics = report.get_weights_metrics()
weights_metrics
# Out:
#                           data_name                     experiment_name  \
# 0           Internet-Advertisements  LiltabEncoder;model_path=resources
# 0                               kc1  LiltabEncoder;model_path=resources
# 0                           phoneme  LiltabEncoder;model_path=resources
# 0                       tic-tac-toe  LiltabEncoder;model_path=resources
# 0                         numerai28  LiltabEncoder;model_path=resources
# 0                               jm1  LiltabEncoder;model_path=resources
# 0                    bank-marketing  LiltabEncoder;model_path=resources
# 0                               kc2  LiltabEncoder;model_path=resources
# 0                          spambase  LiltabEncoder;model_path=resources
# 0                             churn  LiltabEncoder;model_path=resources
# 0                     dresses-sales  LiltabEncoder;model_path=resources
# 0                              wdbc  LiltabEncoder;model_path=resources
# 0                               pc4  LiltabEncoder;model_path=resources
# 0                               pc1  LiltabEncoder;model_path=resources
# 0                       qsar-biodeg  LiltabEncoder;model_path=resources
# 0  climate-model-simulation-crashes  LiltabEncoder;model_path=resources
# 0                             nomao  LiltabEncoder;model_path=resources
# 0                          kr-vs-kp  LiltabEncoder;model_path=resources
# 0                       Bioresponse  LiltabEncoder;model_path=resources
# 0                              wilt  LiltabEncoder;model_path=resources
#
#          norm           std  std_target
# 0   18.566998  6.938894e-18    0.314257
# 0   18.017471  6.397192e-04    0.331857
# 0   26.960268  2.220446e-17    0.335416
# 0    0.000000  0.000000e+00    0.000000
# 0  118.304859  2.775558e-17    0.420245
# 0   42.368964  3.272206e-04    0.265565
# 0   89.612357  2.515349e-17    0.285813
# 0    0.000000  0.000000e+00    0.000000
# 0   26.992451  1.212408e-05    0.271453
# 0   25.287222  1.092566e-07    0.341630
# 0    7.071058  9.990528e-11    0.485386
# 0    7.549814  2.243805e-07    0.372678
# 0   13.272648  0.000000e+00    0.263827
# 0    0.000000  0.000000e+00    0.000000
# 0   11.491846  5.547777e-02    0.383017
# 0    8.474293  2.928274e-07    0.399041
# 0   59.304815  1.842631e-03    0.167496
# 0   20.171795  2.251503e-06    0.221949
# 0   24.814609  6.047072e-05    0.313462
# 0   20.965266  3.538722e-02    0.364795
